# %%
import pandas as pd
import json
import requests
import datetime as datetime
from datetime import date
from dateutil.parser import *

# %%
url = "https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Police_Use_of_Force/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json"

# %%
response = requests.get(url)

# %%
response_json = response.json()

# %%
response_json.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'geometryType', 'spatialReference', 'fields', 'features'])

# %%
[response_json["features"][x]['attributes']['ResponseDate'] for x in range(len(response_json["features"])) if type(response_json["features"][x]['attributes']['ResponseDate']) != int]
# Out:
# [None, None, None, None, None, None, None]

# %%
response_json["features"][30]['attributes'].keys()
# Out:
# dict_keys(['PoliceUseOfForceID', 'CaseNumber', 'ResponseDate', 'Problem', 'Is911Call', 'PrimaryOffense', 'SubjectInjury', 'ForceReportNumber', 'SubjectRole', 'SubjectRoleNumber', 'ForceType', 'ForceTypeAction', 'Race', 'Sex', 'EventAge', 'TypeOfResistance', 'Precinct', 'Neighborhood', 'TotalCityCallsForYear', 'TotalPrecinctCallsForYear', 'TotalNeighborhoodCallsForYear', 'CenterGBSID', 'CenterLatitude', 'CenterLongitude', 'CenterX', 'CenterY', 'DateAdded', 'OBJECTID'])

# %%
new_dict = {}
new_dict["Year"] = []
new_dict["YearMonth"] = []
new_dict["Hour"] = []
# new_dict["geometry"] = []
for field in response_json["features"][0]['attributes'].keys():
    new_dict[field] = []
for index in range(len(response_json["features"])):
    a = response_json["features"][index]['attributes']
    b = response_json["features"][index]['geometry']
    
    if a['ResponseDate'] != None:
    
        for key in response_json["features"][index]['attributes']:
        
        
        
            if key == 'ResponseDate':
                    d = datetime.datetime.fromtimestamp(a[key]/1000)
                    e = d.strftime('%Y-%m-%d')
                    # e = d.strftime('%Y-%m-%d %H:%M:%S')
                    new_dict[key].append(e)
                    new_dict["Year"].append(d.strftime('%Y'))
                    new_dict["YearMonth"].append(d.strftime('%Y-%m'))
                    new_dict["Hour"].append(d.strftime('%H'))
            else:
                new_dict[key].append(a[key])
                # new_dict["geometry"].append(b)
    
    
    else:
        pass


    
df = pd.DataFrame(new_dict)

# %%
type(new_dict['Year'][0])
# Out:
# str

# %%
# Map Data Table - CaseNumber, Lat, Long, Neighborhood, Precinct
# Incident Data Table - everything else

# %%
import sqlite3

# %%
sqlite3.connect('MNPDUseofForce.sqlite')

# %%
cursor = connection.cursor()

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///MNPDUseofForce.sqlite')

# %%
df.to_sql('MNPD_tbl', con=engine, if_exists='replace', index=False)

# %%
conn = engine.connect()
results = pd.read_sql("SELECT Year FROM MNPD_tbl", conn)

# %%
results.count()
# Out:
# Year    33774
# dtype: int64

# %%
engine = create_engine("sqlite:///MNPDUseofForce.sqlite")
data = engine.execute("SELECT Problem FROM MNPD_tbl WHERE Year = 2010")

# %%
list(data)
# Out:
# [('Person with a Gun ',),
#  ('Unwanted Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Attempt Pick-Up ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Disturbance ',),
#  ('Loud Party ',),
#  ('Unwanted Person ',),
#  ('Unknown Wireless/Cell Phone',),
#  ('Traffic Law Enforcement ',),
#  ('On Site ',),
#  ('Check the Welfare ',),
#  ('Check the Welfare ',),
#  ('Traffic Law Enforcement ',),
#  ('Officer Needs Help ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Motor Vehicle Chase ',),
#  ('Fight ',),
#  ('Unwanted Person ',),
#  ('Unwanted Person ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Unknown Trouble ',),
#  ('Fight ',),
#  ('Loud Party ',),
#  ('Disturbance ',),
#  ('Poss Personal Injury Acc ',),
#  ('Crim Sex Conduct ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Miscellaneous ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Prowler ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Check the Welfare ',),
#  ('Traffic Law Enforcement ',),
#  ('Sound of Shots Fired ',),
#  ('Narcotics ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Property Damage/Hit & Run ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Domestic ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('Assist EMS Personnel ',),
#  ('Suspicious Person ',),
#  ('Lost Child ',),
#  ('Customer Trouble ',),
#  ('Unwanted Person ',),
#  ('Emotionally Disturb Person ',),
#  ('Chase on Foot ',),
#  ('Theft ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Customer Trouble ',),
#  ('Prowler ',),
#  ('Chase on Foot ',),
#  ('Suspicious Person ',),
#  ('Indecent Exposure ',),
#  ('Customer Trouble ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Motor Vehicle Chase ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Damage Property-In Progress',),
#  ('Unwanted Person ',),
#  ('Sound of Shots Fired ',),
#  ('Suspicious Person ',),
#  ('Assist an Officer ',),
#  ('Fight ',),
#  ('Damage Property-In Progress',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Suspicious Vehicle ',),
#  ('Person with a Gun ',),
#  ('Animal Call ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Unknown Trouble ',),
#  ('Tenant Trouble ',),
#  ('Unknown Wireless/Cell Phone',),
#  ('Sound of Shots Fired ',),
#  ('Chase on Foot ',),
#  ('Robbery Dwell in Progress ',),
#  ('Assault in Progress ',),
#  ('Assist Other Agency ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Unwanted Person ',),
#  ('Suspicious Vehicle ',),
#  ('Person with a Gun ',),
#  ('Drunk/Intoxicated Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Assist Other Agency ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Check the Welfare ',),
#  ('Fight ',),
#  ('Emotionally Disturb Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('On Site ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Transportation ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Fight ',),
#  ('Domestic ',),
#  ('Fight ',),
#  ('Slumper ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Audible Residential Alarm ',),
#  ('Narcotics ',),
#  ('Unknown Trouble ',),
#  ('Sound of Shots Fired ',),
#  ('Chase on Foot ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Robbery of Person ',),
#  ('Suspicious Person ',),
#  ('Assist EMS Personnel ',),
#  ('Traffic Law Enforcement ',),
#  ('Attempt Pick-Up ',),
#  ('Fight ',),
#  ('Motor Vehicle Chase ',),
#  ('Theft-Hold One Cooperative ',),
#  ('Fight ',),
#  ('Suspicious Vehicle ',),
#  ('On Site ',),
#  ('Suspicious Person ',),
#  ('Emotionally Disturb Person ',),
#  ('Unwanted Person ',),
#  ('Officer Needs Help ',),
#  ('On Site ',),
#  ('Check the Welfare ',),
#  ('Domestic ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Customer Trouble ',),
#  ('Domestic ',),
#  ('Assist EMS Personnel ',),
#  ('Person with a Gun ',),
#  ('Disturbance ',),
#  ('Robbery Dwell in Progress ',),
#  ('Chase on Foot ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Vehicle ',),
#  ('Unwanted Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Attempt Pick-Up ',),
#  ('Suspicious Vehicle ',),
#  ('Traffic Law Enforcement ',),
#  ('Emotionally Disturb Person ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Assist EMS Personnel ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Motor Vehicle Chase ',),
#  ('Suspicious Person ',),
#  ('Check the Welfare ',),
#  ('Damage Property-In Progress',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Motor Vehicle Chase ',),
#  ('Check the Welfare ',),
#  ('Domestic ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Assist EMS Personnel ',),
#  ('Customer Trouble ',),
#  ('Disturbance ',),
#  ('Chase on Foot ',),
#  ('Customer Trouble ',),
#  ('Fight ',),
#  ('Damage Property-In Progress',),
#  ('Property Damage Accident ',),
#  ('Suspicious Vehicle ',),
#  ('Theft ',),
#  ('Indecent Exposure ',),
#  ('Fight ',),
#  ('Robbery of Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Narcotics ',),
#  ('Officer Needs Help ',),
#  ('Disturbance ',),
#  ('Robbery of Person ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('On Site ',),
#  ('Domestic ',),
#  ('Person with a Gun ',),
#  ('Damage Property-In Progress',),
#  ('Emotionally Disturb Person ',),
#  ('Fight ',),
#  ('Assist Other Agency ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Chase on Foot ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Unwanted Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Loud Party ',),
#  ('On Site ',),
#  ('Person with a Gun ',),
#  ('Domestic ',),
#  ('Suspicious Person ',),
#  ('Domestic ',),
#  ('Officer Needs Help ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Customer Trouble ',),
#  ('Person with a Gun ',),
#  ('Unwanted Person ',),
#  ('Narcotics ',),
#  ('Miscellaneous ',),
#  ('Miscellaneous ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Domestic ',),
#  ('Traffic Law Enforcement ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Miscellaneous ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Domestic ',),
#  ('Suspicious Person ',),
#  ('Domestic ',),
#  ('Narcotics ',),
#  ('Person with a Gun ',),
#  ('Domestic ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Domestic ',),
#  ('Customer Trouble ',),
#  ('Suspicious Person ',),
#  ('Suspicious Vehicle ',),
#  ('Chase on Foot ',),
#  ('Chase on Foot ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Sound of Shots Fired ',),
#  ('Fight ',),
#  ('Chase on Foot ',),
#  ('Disturbance ',),
#  ('Assist an Officer ',),
#  ('Disturbance ',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('Check the Welfare ',),
#  ('Prowler ',),
#  ('Transportation ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Assault in Progress ',),
#  ('Person with a Weapon ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Prowler ',),
#  ('Silent Alarm ',),
#  ('Check the Welfare ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('On Site ',),
#  ('Narcotics ',),
#  ('Sound of Shots Fired ',),
#  ('Motor Vehicle Chase ',),
#  ('Fight ',),
#  ('Unknown Wireless/Cell Phone',),
#  ('Suspicious Person ',),
#  ('High Risk Warrant Entry ',),
#  ('Theft ',),
#  ('Indecent Exposure ',),
#  ('Fight ',),
#  ('Chase on Foot ',),
#  ('Fight ',),
#  ('Suspicious Vehicle ',),
#  ('Officer Needs Help ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Unknown Trouble ',),
#  ('Fight ',),
#  ('Officer Needs Help ',),
#  ('Suspicious Vehicle ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Narcotics ',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('Person with a Gun ',),
#  ('Unknown Trouble ',),
#  ('Unknown Trouble ',),
#  ('Unknown Trouble ',),
#  ('Traffic Law Enforcement ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Crim Sex Conduct ',),
#  ('Theft ',),
#  ('Suspicious Person ',),
#  ('Miscellaneous ',),
#  ('Suspicious Vehicle ',),
#  ('Traffic Law Enforcement ',),
#  ('Unwanted Person ',),
#  ('Fight ',),
#  ('Assault in Progress ',),
#  ('Music-Loud ',),
#  ('Sound of Shots Fired ',),
#  ('Suspicious Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Narcotics ',),
#  ('Loud Party ',),
#  ('Suspicious Person ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Vehicle ',),
#  ('Crim Sex Conduct ',),
#  ('Crim Sex Conduct/Report ',),
#  ('Suspicious Vehicle ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Unknown Trouble ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('On Site ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Disturbance ',),
#  ('Narcotics ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Suspicious Vehicle ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Prowler ',),
#  ('Unwanted Person ',),
#  ('Suspicious Person ',),
#  ('Customer Trouble ',),
#  ('Suspicious Person ',),
#  ('Attempt Pick-Up ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Vehicle ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Suspicious Vehicle ',),
#  ('Unknown Trouble ',),
#  ('Assault in Progress ',),
#  ('Check the Welfare ',),
#  ('Emotionally Disturb Person ',),
#  ('Fight ',),
#  ('On Site ',),
#  ('Loud Party ',),
#  ('Disturbance ',),
#  ('Motor Vehicle Chase ',),
#  ('Assault in Progress ',),
#  ('Customer Trouble ',),
#  ('Assist Other Agency ',),
#  ('Disturbance ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Damage Property-In Progress',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('High Risk Warrant Entry ',),
#  ('Chase on Foot ',),
#  ('Chase on Foot ',),
#  ('Suspicious Person ',),
#  ('Assault in Progress ',),
#  ('Walk Through a Building ',),
#  ('Disturbance ',),
#  ('Domestic ',),
#  ('Person with a Weapon ',),
#  ('Disturbance ',),
#  ('Unwanted Person ',),
#  ('Motor Vehicle Chase ',),
#  ('Loud Party ',),
#  ('Assault in Progress ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Unwanted Person ',),
#  ('Crim Sex Conduct/Report ',),
#  ('Disturbance ',),
#  ('Domestic ',),
#  ('Officer Needs Help ',),
#  ('Property Damage Accident ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('High Risk Warrant Entry ',),
#  ('Sound of Shots Fired ',),
#  ('Emotionally Disturb Person ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Domestic ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Assault in Progress ',),
#  ('Unknown Wireless/Cell Phone',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Theft ',),
#  ('On Site ',),
#  ('Person with a Gun ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('High Risk Warrant Entry ',),
#  ('Suspicious Person ',),
#  ('Narcotics ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Music-Loud ',),
#  ('Unknown Trouble ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Robbery Dwell in Progress ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Assist Other Agency ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Miscellaneous ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Traffic Law Enforcement ',),
#  ('Assist Other Agency ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Officer Needs Help ',),
#  ('Suspicious Vehicle ',),
#  ('Suspicious Person ',),
#  ('Assist Other Agency ',),
#  ('Person with a Gun ',),
#  ('Unknown Wireless/Cell Phone',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('High Risk Warrant Entry ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Assist EMS Personnel ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Robbery of Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Emotionally Disturb Person ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Person with a Weapon ',),
#  ('Stabbing ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Vehicle ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Officer Needs Help ',),
#  ('Check the Welfare ',),
#  ('Suspicious Person ',),
#  ('Music-Loud ',),
#  ('Assist Fire Personnel ',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('Suspicious Vehicle ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Fight ',),
#  ('On Site ',),
#  ('Sound of Shots Fired ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Customer Trouble ',),
#  ('Traffic Law Enforcement ',),
#  ('Assault in Progress ',),
#  ('Disturbance ',),
#  ('Suspicious Vehicle ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Person with a Gun ',),
#  ('Suspicious Vehicle ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Robbery of Person ',),
#  ('Crim Sex Conduct ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Bait Vehicle Auto Theft ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Bait Vehicle Auto Theft ',),
#  ('Suspicious Person ',),
#  ('Customer Trouble ',),
#  ('Narcotics ',),
#  ('Person with a Gun ',),
#  ('Fight ',),
#  ('Unknown Trouble ',),
#  ('Customer Trouble ',),
#  ('Chase on Foot ',),
#  ('Chase on Foot ',),
#  ('Fight ',),
#  ('Miscellaneous ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Domestic ',),
#  ('Domestic ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Assist Other Agency ',),
#  ('Robbery of Person ',),
#  ('Unwanted Person ',),
#  ('Disturbance ',),
#  ('Stabbing ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Person with a Gun ',),
#  ('Disturbance ',),
#  ('Person with a Gun ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Domestic ',),
#  ('Suspicious Vehicle ',),
#  ('Suspicious Person ',),
#  ('Down Outside-One ',),
#  ('Trespass in Boarded Dwell ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Fight ',),
#  ('Indecent Exposure ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('High Risk Warrant Entry ',),
#  ('Disturbance ',),
#  ('Customer Trouble ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Motor Vehicle Chase ',),
#  ('Suspicious Person ',),
#  ('Domestic ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('Check the Welfare ',),
#  ('Domestic ',),
#  ('Traffic Law Enforcement ',),
#  ('Customer Trouble ',),
#  ('Robbery of Person ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Check the Welfare ',),
#  ('Chase on Foot ',),
#  ('Suspicious Vehicle ',),
#  ('Suspicious Person ',),
#  ('On Site ',),
#  ('Domestic ',),
#  ('Fight ',),
#  ('Drunk/Intoxicated Person ',),
#  ('Suspicious Person ',),
#  ('Poss Personal Injury Acc ',),
#  ('Narcotics ',),
#  ('Unknown Trouble ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Down Outside-One ',),
#  ('Transportation ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Unwanted Person ',),
#  ('Fight ',),
#  ('Down Outside-One w/Fire ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Assault in Progress ',),
#  ('Robbery of Person ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Fight ',),
#  ('Suspicious Vehicle ',),
#  ('Disturbance ',),
#  ('High Risk Warrant Entry ',),
#  ('Attempt Pick-Up ',),
#  ('Miscellaneous ',),
#  ('Assault in Progress ',),
#  ('Motor Vehicle Chase ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Domestic ',),
#  ('Domestic ',),
#  ('Fight ',),
#  ('Down Outside-One ',),
#  ('Assault in Progress ',),
#  ('Chase on Foot ',),
#  ('Suspicious Vehicle ',),
#  ('Robbery of Person ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Chase on Foot ',),
#  ('Traffic Law Enforcement ',),
#  ('Neighbor Trouble ',),
#  ('Officer Needs Help ',),
#  ('Domestic ',),
#  ('Damage Property-In Progress',),
#  ('Damage Property-In Progress',),
#  ('Suspicious Person ',),
#  ('Loud Party ',),
#  ('Fight ',),
#  ('Emotionally Disturb Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Officer Needs Help ',),
#  ('Loud Party ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Person with a Weapon ',),
#  ('Suspicious Vehicle ',),
#  ('Miscellaneous ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Motor Vehicle Chase ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Person ',),
#  ('Crim Sex Conduct ',),
#  ('Traffic Law Enforcement ',),
#  ('Loud Party ',),
#  ('Robbery Dwell in Progress ',),
#  ('High Risk Warrant Entry ',),
#  ('Bait Vehicle Auto Theft ',),
#  ('Disturbance ',),
#  ('Poss Personal Injury Acc ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Motor Vehicle Chase ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Fight ',),
#  ('Customer Trouble ',),
#  ('Crim Sex Conduct ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Vehicle ',),
#  ('Theft ',),
#  ('Disturbance ',),
#  ('Unwanted Person ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Assault in Progress ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Unknown Trouble ',),
#  ('Person with a Gun ',),
#  ('Fight ',),
#  ('Suspicious Vehicle ',),
#  ('ShotSpotter Activation ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Assault in Progress ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('High Risk Warrant Entry ',),
#  ('Unwanted Person ',),
#  ('Suspicious Vehicle ',),
#  ('Suspicious Person ',),
#  ('Indecent Exposure ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Assist an Officer ',),
#  ('Person with a Weapon ',),
#  ('Assist Other Agency ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Chase on Foot ',),
#  ('Indecent Exposure ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Disturbance ',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Robbery Dwell in Progress ',),
#  ('Domestic ',),
#  ('Chase on Foot ',),
#  ('Suspicious Vehicle ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Unknown Trouble ',),
#  ('Assist an Officer ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Officer Needs Help ',),
#  ('Unwanted Person ',),
#  ('Suspicious Person ',),
#  ('Assist Fire Personnel ',),
#  ('Unknown Trouble ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Assault in Progress ',),
#  ('Suspicious Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Traffic Law Enforcement ',),
#  ('Domestic ',),
#  ('Suspicious Vehicle ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Disturbance ',),
#  ('Assault in Progress ',),
#  ('Officer Needs Help ',),
#  ('Disturbance ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('Assist Other Agency ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Assault in Progress ',),
#  ('Domestic ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Disturbance ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Suspicious Vehicle ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Domestic ',),
#  ('Chase on Foot ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Traffic Law Enforcement ',),
#  ('Traffic Law Enforcement ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Chase on Foot ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Assist an Officer ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Chase on Foot ',),
#  ('Disturbance ',),
#  ('High Risk Warrant Entry ',),
#  ('On Site ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Domestic ',),
#  ('Officer Needs Help ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('Disturbance ',),
#  ('Narcotics ',),
#  ('Traffic Law Enforcement ',),
#  ('Damage Property-In Progress',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('High Risk Warrant Entry ',),
#  ('Assault in Progress ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Person with a Gun ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Bait Vehicle Auto Theft ',),
#  ('Suspicious Person ',),
#  ('Domestic ',),
#  ('Property Damage Accident ',),
#  ('Suspicious Person ',),
#  ('Fight ',),
#  ('Suspicious Vehicle ',),
#  ('Officer Needs Help ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Fight ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Fight ',),
#  ('Suspicious Person ',),
#  ('Unwanted Person ',),
#  ('Traffic Law Enforcement ',),
#  ('Domestic ',),
#  ('Traffic Law Enforcement ',),
#  ('Assault in Progress ',),
#  ('Fight ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Suspicious Vehicle ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Crim Sex Conduct/Report ',),
#  ('Suspicious Vehicle ',),
#  ('Disturbance ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Crim Sex Conduct/Report ',),
#  ('Assault in Progress ',),
#  ('Assault in Progress ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ('Unknown Trouble ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Traffic Law Enforcement ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Suspicious Vehicle ',),
#  ('Suspicious Vehicle ',),
#  ('Crim Sex Conduct/Report ',),
#  ('Suspicious Person ',),
#  ('Neighbor Trouble ',),
#  ('ShotSpotter Activation ',),
#  ('Unknown Trouble ',),
#  ('Domestic Abuse-In Progress ',),
#  ('Suspicious Vehicle ',),
#  ('Prowler ',),
#  ('Suspicious Vehicle ',),
#  ('Domestic ',),
#  ('Suspicious Person ',),
#  ('Assist Other Agency ',),
#  ('Suspicious Person ',),
#  ('Suspicious Person ',),
#  ('Narcotics ',),
#  ('Disturbance ',),
#  ('Person with a Gun ',),
#  ('Suspicious Person ',),
#  ('Suspected Hazard ',),
#  ('Narcotics ',),
#  ('Traffic Law Enforcement ',),
#  ('Fight ',),
#  ('Burglary Dwlng In Progress ',),
#  ('Fight ',),
#  ('Attempt Pick-Up ',),
#  ('Suspicious Person ',),
#  ('Person with a Gun ',),
#  ('Unwanted Person ',),
#  ('Person with a Gun ',),
#  ('Traffic Law Enforcement ',),
#  ('Suspicious Person ',),
#  ...]

# %%
df.head()
# Out:
#    Year YearMonth Hour  PoliceUseOfForceID CaseNumber ResponseDate  \
# 0  2008   2008-01   19            24577528  08-016365   2008-01-16
# 1  2008   2008-01   16            24577529  08-018973   2008-01-19
# 2  2008   2008-02   13            24577530  08-044382   2008-02-15
# 3  2008   2008-02   13            24577531  08-052065   2008-02-23
# 4  2008   2008-02   20            24577532  08-052540   2008-02-23
#
#                Problem Is911Call PrimaryOffense SubjectInjury  ...  \
# 0  Suspicious Vehicle         No             WT          None  ...
# 1  Suspicious Vehicle         No         RECVEH            No  ...
# 2     Unwanted Person        Yes          FORCE           Yes  ...
# 3            Domestic        Yes         OBSTRU            No  ...
# 4               Fight         No         OBSTRU            No  ...
#
#    TotalCityCallsForYear TotalPrecinctCallsForYear  \
# 0                 322402                     84018
# 1                 322402                     80434
# 2                 322402                     48901
# 3                 322402                     84018
# 4                 322402                     46998
#
#    TotalNeighborhoodCallsForYear CenterGBSID CenterLatitude CenterLongitude  \
# 0                           7167       22831      44.953746      -93.250552
# 1                          13679       18761      45.010118      -93.286438
# 2                           1370       15283      45.005276      -93.263861
# 3                            850       14695      44.903566      -93.218444
# 4                          23458       17120      44.981655      -93.271963
#
#         CenterX       CenterY      DateAdded OBJECTID
# 0 -1.038060e+07  5.614243e+06  1627028370000        1
# 1 -1.038460e+07  5.623115e+06  1627028370000        2
# 2 -1.038209e+07  5.622352e+06  1627028370000        3
# 3 -1.037703e+07  5.606353e+06  1627028370000        4
# 4 -1.038299e+07  5.618634e+06  1627028370000        5
#
# [5 rows x 31 columns]
